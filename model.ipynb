# %%
cd /content/drive/My Drive/Gender Classification
# Out:
# /content/drive/My Drive/Gender Classification

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip 13_7651_compressed_NationalNames.csv.zip
# Out:
# Archive:  13_7651_compressed_NationalNames.csv.zip
# replace NationalNames.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %%
import numpy as np
import pandas as pd

# %%
dataset1=pd.read_csv('NationalNames.csv')
dataset2=pd.read_csv('name.csv')
dataset3=pd.read_csv('indiannames.csv')
dataset4=pd.read_csv('nam.csv')
dataset5=pd.read_csv('SSA_Names.csv')

# %%
dataset1=dataset1.loc[:,['Name','Gender']]
dataset2=dataset2.loc[:,['Name','Gender']]
dataset3=dataset3.loc[:,['Name','Gender']]
dataset4=dataset4.loc[:,['Name','Gender']]
dataset5=dataset5.loc[:,['Name','Gender']]

# %%
data=pd.concat([dataset1,dataset2,dataset3,dataset4,dataset5])

# %%
data=data.reset_index()

# %%
dataset=data.drop(['index'],axis=1)

# %%
dataset
# Out:
#               Name Gender
# 0             Mary      F
# 1             Anna      F
# 2             Emma      F
# 3        Elizabeth      F
# 4           Minnie      F
# ...            ...    ...
# 1994026     Zykell      M
# 1994027     Zyking      M
# 1994028      Zykir      M
# 1994029      Zyrus      M
# 1994030       Zyus      M
#
# [1994031 rows x 2 columns]

# %%
len(dataset['Name'].unique())
# Out:
# 110000

# %%
dataset.drop_duplicates('Name',ignore_index=True,inplace=True)

# %%
dataset.isnull().values.any()
# Out:
# True

# %%
dataset=dataset.dropna()

# %%
dataset.isnull().values.any()
# Out:
# False

# %%
name=dataset['Name']

# %%
len(name.unique())
# Out:
# 109999

# %%
name=list(name)

# %%
label=list(dataset['Gender'])

# %%
label
# Out:
# ['F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  'M',
#  ...]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
labels=le.fit_transform(label)

# %%
labels
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
le.classes_
# Out:
# array(['F', 'M'], dtype='<U1')

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer(analyzer='char')

# %%
names=cv.fit_transform(name).toarray()

# %%
len(names[1])
# Out:
# 26

# %%
from sklearn.model_selection import train_test_split
feature_train,feature_test,label_train,label_test=train_test_split(names,labels,test_size=0.2,random_state=42)

# %%
from sklearn.naive_bayes import MultinomialNB
model=MultinomialNB()
model.fit(feature_train,label_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
label_pred=model.predict(feature_test)

# %%
import sklearn.metrics as m

# %%
m.accuracy_score(label_test,label_pred)
# Out:
# 0.6785909090909091

# %% [markdown]
# LSTM

# %%
from keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(char_level=True)
tokenizer.fit_on_texts(name)
sequence_of_int = tokenizer.texts_to_sequences(name)

# %%
from keras.preprocessing.sequence import pad_sequences
padsequences=pad_sequences(sequence_of_int,maxlen=15,padding='post')

# %%
len(padsequences[2])
# Out:
# 15

# %%
from keras.utils.np_utils import to_categorical
labels=to_categorical(labels)

# %%
from keras.models import Sequential
from keras.layers import Dense,LSTM,Embedding,Dropout

# %%
padsequences.shape
# Out:
# (109999, 15)

# %%
from sklearn.model_selection import train_test_split
feature_train,feature_test,label_train,label_test=train_test_split(padsequences,labels,test_size=0.1,random_state=42)

# %%
model=Sequential()
model.add(Embedding(26,64,input_length=15))
model.add(LSTM(2048,return_sequences=True))
model.add(LSTM(256,return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(2,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 15, 64)            1664
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 15, 2048)          17309696
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 256)               2360320
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 19,672,194
# Trainable params: 19,672,194
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(feature_train,label_train,epochs=50,validation_data=(feature_test,label_test),batch_size=1000)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 98999 samples, validate on 11000 samples
# Epoch 1/50
# 98999/98999 [==============================] - 32s 325us/step - loss: 0.5590 - accuracy: 0.7127 - val_loss: 0.4793 - val_accuracy: 0.7755
# Epoch 2/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.4414 - accuracy: 0.7971 - val_loss: 0.4246 - val_accuracy: 0.8062
# Epoch 3/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.4127 - accuracy: 0.8146 - val_loss: 0.4102 - val_accuracy: 0.8155
# Epoch 4/50
# 98999/98999 [==============================] - 31s 318us/step - loss: 0.3996 - accuracy: 0.8215 - val_loss: 0.3990 - val_accuracy: 0.8245
# Epoch 5/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.3891 - accuracy: 0.8258 - val_loss: 0.3943 - val_accuracy: 0.8234
# Epoch 6/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.3776 - accuracy: 0.8331 - val_loss: 0.3762 - val_accuracy: 0.8339
# Epoch 7/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.3683 - accuracy: 0.8385 - val_loss: 0.3628 - val_accuracy: 0.8409
# Epoch 8/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.3584 - accuracy: 0.8438 - val_loss: 0.3558 - val_accuracy: 0.8411
# Epoch 9/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.3423 - accuracy: 0.8516 - val_loss: 0.3452 - val_accuracy: 0.8500
# Epoch 10/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.3323 - accuracy: 0.8576 - val_loss: 0.3388 - val_accuracy: 0.8519
# Epoch 11/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.3195 - accuracy: 0.8641 - val_loss: 0.3322 - val_accuracy: 0.8571
# Epoch 12/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.3051 - accuracy: 0.8700 - val_loss: 0.3119 - val_accuracy: 0.8646
# Epoch 13/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.2953 - accuracy: 0.8750 - val_loss: 0.3075 - val_accuracy: 0.8710
# Epoch 14/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.2806 - accuracy: 0.8830 - val_loss: 0.2992 - val_accuracy: 0.8731
# Epoch 15/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.2649 - accuracy: 0.8902 - val_loss: 0.2988 - val_accuracy: 0.8768
# Epoch 16/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.2504 - accuracy: 0.8965 - val_loss: 0.2918 - val_accuracy: 0.8781
# Epoch 17/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.2335 - accuracy: 0.9037 - val_loss: 0.2802 - val_accuracy: 0.8828
# Epoch 18/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.2163 - accuracy: 0.9116 - val_loss: 0.2885 - val_accuracy: 0.8847
# Epoch 19/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.1979 - accuracy: 0.9188 - val_loss: 0.2893 - val_accuracy: 0.8795
# Epoch 20/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.1792 - accuracy: 0.9272 - val_loss: 0.3045 - val_accuracy: 0.8834
# Epoch 21/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.1619 - accuracy: 0.9348 - val_loss: 0.3057 - val_accuracy: 0.8865
# Epoch 22/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.1444 - accuracy: 0.9420 - val_loss: 0.3094 - val_accuracy: 0.8851
# Epoch 23/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.1262 - accuracy: 0.9500 - val_loss: 0.3236 - val_accuracy: 0.8896
# Epoch 24/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.1102 - accuracy: 0.9564 - val_loss: 0.3428 - val_accuracy: 0.8837
# Epoch 25/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.0963 - accuracy: 0.9620 - val_loss: 0.3883 - val_accuracy: 0.8907
# Epoch 26/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.0814 - accuracy: 0.9680 - val_loss: 0.3953 - val_accuracy: 0.8825
# Epoch 27/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.0717 - accuracy: 0.9723 - val_loss: 0.4050 - val_accuracy: 0.8849
# Epoch 28/50
# 98999/98999 [==============================] - 31s 318us/step - loss: 0.0594 - accuracy: 0.9773 - val_loss: 0.4506 - val_accuracy: 0.8832
# Epoch 29/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.0503 - accuracy: 0.9807 - val_loss: 0.4672 - val_accuracy: 0.8810
# Epoch 30/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.0437 - accuracy: 0.9831 - val_loss: 0.4630 - val_accuracy: 0.8854
# Epoch 31/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.0391 - accuracy: 0.9857 - val_loss: 0.5024 - val_accuracy: 0.8851
# Epoch 32/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.0334 - accuracy: 0.9873 - val_loss: 0.4711 - val_accuracy: 0.8841
# Epoch 33/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.0286 - accuracy: 0.9895 - val_loss: 0.5250 - val_accuracy: 0.8846
# Epoch 34/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.0266 - accuracy: 0.9900 - val_loss: 0.5280 - val_accuracy: 0.8851
# Epoch 35/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.0231 - accuracy: 0.9916 - val_loss: 0.5550 - val_accuracy: 0.8848
# Epoch 36/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.0234 - accuracy: 0.9914 - val_loss: 0.5223 - val_accuracy: 0.8867
# Epoch 37/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.0224 - accuracy: 0.9918 - val_loss: 0.5387 - val_accuracy: 0.8859
# Epoch 38/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.0191 - accuracy: 0.9930 - val_loss: 0.5818 - val_accuracy: 0.8854
# Epoch 39/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.0203 - accuracy: 0.9927 - val_loss: 0.5544 - val_accuracy: 0.8862
# Epoch 40/50
# 98999/98999 [==============================] - 31s 316us/step - loss: 0.0193 - accuracy: 0.9928 - val_loss: 0.5941 - val_accuracy: 0.8863
# Epoch 41/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.0183 - accuracy: 0.9931 - val_loss: 0.5953 - val_accuracy: 0.8878
# Epoch 42/50
# 98999/98999 [==============================] - 31s 316us/step - loss: 0.0165 - accuracy: 0.9936 - val_loss: 0.6225 - val_accuracy: 0.8848
# Epoch 43/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.0182 - accuracy: 0.9930 - val_loss: 0.5827 - val_accuracy: 0.8861
# Epoch 44/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.0164 - accuracy: 0.9933 - val_loss: 0.6028 - val_accuracy: 0.8855
# Epoch 45/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.0186 - accuracy: 0.9926 - val_loss: 0.5754 - val_accuracy: 0.8846
# Epoch 46/50
# 98999/98999 [==============================] - 31s 316us/step - loss: 0.0176 - accuracy: 0.9932 - val_loss: 0.5874 - val_accuracy: 0.8858
# Epoch 47/50
# 98999/98999 [==============================] - 31s 316us/step - loss: 0.0181 - accuracy: 0.9928 - val_loss: 0.5728 - val_accuracy: 0.8871
# Epoch 48/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.0157 - accuracy: 0.9933 - val_loss: 0.6025 - val_accuracy: 0.8869
# Epoch 49/50
# 98999/98999 [==============================] - 31s 317us/step - loss: 0.0126 - accuracy: 0.9948 - val_loss: 0.6575 - val_accuracy: 0.8904
# Epoch 50/50
# 98999/98999 [==============================] - 31s 316us/step - loss: 0.0139 - accuracy: 0.9942 - val_loss: 0.5817 - val_accuracy: 0.8877

# %%
model.save('model.h5')

# %%
import sklearn.metrics as m

# %%
label_pred=model.predict(feature_test)

# %%
label_pred=np.argmax(label_pred,axis=1)

# %%
label_pred
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
l_test=np.argmax(label_test,axis=1)

# %%
m.accuracy_score(l_test,label_pred)
# Out:
# 0.8865454545454545

# %%
print(m.classification_report(l_test,label_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91      6726
#            1       0.85      0.86      0.85      4274
#
#     accuracy                           0.89     11000
#    macro avg       0.88      0.88      0.88     11000
# weighted avg       0.89      0.89      0.89     11000

# %%
m.confusion_matrix(l_test,label_pred)
# Out:
# array([[6074,  652],
#        [ 596, 3678]])

# %%
from keras.models import load_model

# %%
import pickle

# %%
pickle.dump(tokenizer,open('tokenizer.pkl','wb+'),protocol=pickle.HIGHEST_PROTOCOL)

# %%
tokenizer=pickle.load(open('tokenizer.pkl','rb+'))

# %%
tokenizer.index_word
# Out:
# {1: 'a',
#  2: 'e',
#  3: 'n',
#  4: 'i',
#  5: 'r',
#  6: 'l',
#  7: 's',
#  8: 'h',
#  9: 't',
#  10: 'o',
#  11: 'y',
#  12: 'm',
#  13: 'd',
#  14: 'k',
#  15: 'u',
#  16: 'c',
#  17: 'j',
#  18: 'b',
#  19: 'v',
#  20: 'g',
#  21: 'z',
#  22: 'p',
#  23: 'w',
#  24: 'f',
#  25: 'q',
#  26: 'x'}

# %%
def input(n):
  q=tokenizer.texts_to_sequences(n)
  q=[i[0] for i in q]
  q1=[]
  q1.append(q)
  s=pad_sequences(q1,maxlen=15,padding='post')
  return s

# %%
tokenizer.texts_to_sequences('kamesh')
# Out:
# [[14], [1], [12], [2], [7], [8]]

# %%
input('kamesh')
# Out:
# array([[14,  1, 12,  2,  7,  8,  0,  0,  0,  0,  0,  0,  0,  0,  0]],
#       dtype=int32)

# %%
def pred(n):
  w=model.predict(input(n))
  w=np.argmax(w,axis=1)
  return w[0]

# %%
pred('kamesh')
# Out:
# 1

# %%
pred('rajesh')
# Out:
# 1

# %%
pred('sudha')
# Out:
# 0

# %%
pred('srihasa')
# Out:
# 0

# %%
pred('Alex')
# Out:
# 1

# %%
pred('preethi')
# Out:
# 0

# %%
pred('John')
# Out:
# 0

# %%
pred('mahesh')
# Out:
# 1

# %%
pred('raju')
# Out:
# 1

# %%
pred('abhitha')
# Out:
# 1

# %%
pred('ratnamahadevi')
# Out:
# 0

# %%
pred('srimukhi')
# Out:
# 0

# %%
pred('rajashekhar')
# Out:
# 1

# %%
pred('manga')
# Out:
# 0

# %%
pred('katyayani')
# Out:
# 0

# %%
pred('prakash')
# Out:
# 1

# %%
pred('shanmukh')
# Out:
# 1

# %%
pred('bhargav')
# Out:
# 1

# %%
pred('aditya')
# Out:
# 1

# %%
pred('akshar')
# Out:
# 1

# %%
pred('madhav')
# Out:
# 1

# %%
pred('madhavi')
# Out:
# 0

# %%
pred('durga')
# Out:
# 0

# %%
pred('saisudha')
# Out:
# 0

# %%
pred('durgesh')
# Out:
# 1

# %%
pred('rangesh')
# Out:
# 1

# %%
pred('rangarao')
# Out:
# 1

# %%
pred('kameshwari')
# Out:
# 0

# %%
pred('kameswararao')
# Out:
# 1

# %%
model.save('model.h5')

# %%
pred('srilekha')
# Out:
# 0

# %%
pred('srikhar')
# Out:
# 1
